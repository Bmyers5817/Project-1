# %%
# Project 1: World Happiness

# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st
import seaborn as sn

# %%
# Import and read .csv file
happiness_data_2015 = pd.read_csv("data/2015.csv")
happiness_data_2016 = pd.read_csv("data/2016.csv")
happiness_data_2017 = pd.read_csv("data/2017.csv")
happiness_data_2018 = pd.read_csv("data/2018.csv")
happiness_data_2019 = pd.read_csv("data/2019.csv")


happiness_data_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
happiness_data_2015.insert(0, "Year", "2015", True) 

happiness_data_2015.drop(['Region', 'Standard Error', 'Dystopia Residual'], axis=1, inplace=True)
happiness_data_2015.rename({'Happiness Rank':'Overall rank', 
                           'Country':'Country or region', 
                           'Happiness Score': 'Score', 
                           'Economy (GDP per Capita)': 'GDP per capita', 
                           'Family':'Social support', 
                           'Health (Life Expectancy)':'Healthy life expectancy', 
                           'Freedom':'Freedom to make life choices', 
                           'Trust (Government Corruption)':'Perceptions of corruption'}, axis=1, inplace=True)





happiness_data_2015.head()
# Out:
#    Year Country or region  Overall rank  Score  GDP per capita  \
# 0  2015       Switzerland             1  7.587         1.39651
# 1  2015           Iceland             2  7.561         1.30232
# 2  2015           Denmark             3  7.527         1.32548
# 3  2015            Norway             4  7.522         1.45900
# 4  2015            Canada             5  7.427         1.32629
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0         1.34951                  0.94143                       0.66557
# 1         1.40223                  0.94784                       0.62877
# 2         1.36058                  0.87464                       0.64938
# 3         1.33095                  0.88521                       0.66973
# 4         1.32261                  0.90563                       0.63297
#
#    Perceptions of corruption  Generosity
# 0                    0.41978     0.29678
# 1                    0.14145     0.43630
# ...

# %%
happiness_data_2016.insert(0, "Year", "2016", True) 

happiness_data_2016.drop(['Region', 'Lower Confidence Interval', 'Upper Confidence Interval', 'Dystopia Residual'], axis=1, inplace=True)
happiness_data_2016.rename({'Happiness Rank':'Overall rank', 
                           'Country':'Country or region', 
                           'Happiness Score': 'Score', 
                           'Economy (GDP per Capita)': 'GDP per capita', 
                           'Family':'Social support', 
                           'Health (Life Expectancy)':'Healthy life expectancy', 
                           'Freedom':'Freedom to make life choices', 
                           'Trust (Government Corruption)':'Perceptions of corruption'}, axis=1, inplace=True)
happiness_data_2016.head()
# Out:
#    Year Country or region  Overall rank  Score  GDP per capita  \
# 0  2016           Denmark             1  7.526         1.44178
# 1  2016       Switzerland             2  7.509         1.52733
# 2  2016           Iceland             3  7.501         1.42666
# 3  2016            Norway             4  7.498         1.57744
# 4  2016           Finland             5  7.413         1.40598
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0         1.16374                  0.79504                       0.57941
# 1         1.14524                  0.86303                       0.58557
# 2         1.18326                  0.86733                       0.56624
# 3         1.12690                  0.79579                       0.59609
# 4         1.13464                  0.81091                       0.57104
#
#    Perceptions of corruption  Generosity
# 0                    0.44453     0.36171
# 1                    0.41203     0.28083
# ...

# %%
happiness_data_2017.insert(0, "Year", "2017", True)

happiness_data_2017.drop(['Whisker.high', 'Whisker.low', 'Dystopia.Residual'], axis=1, inplace=True)
happiness_data_2017.rename({'Happiness.Rank':'Overall rank', 
                           'Country':'Country or region', 
                           'Happiness.Score': 'Score', 
                           'Economy..GDP.per.Capita.': 'GDP per capita', 
                           'Family':'Social support', 
                           'Health..Life.Expectancy.':'Healthy life expectancy', 
                           'Freedom':'Freedom to make life choices', 
                           'Trust..Government.Corruption.':'Perceptions of corruption'}, axis=1, inplace=True)
happiness_data_2017.head()
# Out:
#    Year Country or region  Overall rank  Score  GDP per capita  \
# 0  2017            Norway             1  7.537        1.616463
# 1  2017           Denmark             2  7.522        1.482383
# 2  2017           Iceland             3  7.504        1.480633
# 3  2017       Switzerland             4  7.494        1.564980
# 4  2017           Finland             5  7.469        1.443572
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0        1.533524                 0.796667                      0.635423
# 1        1.551122                 0.792566                      0.626007
# 2        1.610574                 0.833552                      0.627163
# 3        1.516912                 0.858131                      0.620071
# 4        1.540247                 0.809158                      0.617951
#
#    Generosity  Perceptions of corruption
# 0    0.362012                   0.315964
# 1    0.355280                   0.400770
# ...

# %%
happiness_data_2018.insert(0, "Year", "2018", True)
happiness_data_2019.insert(0, "Year", "2019", True)

# %%
happiness_data = pd.concat([happiness_data_2019, happiness_data_2018, happiness_data_2017, happiness_data_2016, happiness_data_2015]).reset_index()

happiness_data.head(100)
# Out:
#     index  Year  Overall rank Country or region  Score  GDP per capita  \
# 0       0  2019             1           Finland  7.769           1.340
# 1       1  2019             2           Denmark  7.600           1.383
# 2       2  2019             3            Norway  7.554           1.488
# 3       3  2019             4           Iceland  7.494           1.380
# 4       4  2019             5       Netherlands  7.488           1.396
# ..    ...   ...           ...               ...    ...             ...
# 95     95  2019            96          Cameroon  5.044           0.549
# 96     96  2019            97          Bulgaria  5.011           1.092
# 97     97  2019            98             Ghana  4.996           0.611
# 98     98  2019            99       Ivory Coast  4.944           0.569
# 99     99  2019           100             Nepal  4.913           0.446
#
#     Social support  Healthy life expectancy  Freedom to make life choices  \
# ...

# %%
happiness_data["Country or region"].replace("Taiwan Province of China", "Taiwan", inplace = True)
happiness_data["Country or region"].replace("Hong Kong S.A.R., China", "Hong Kong", inplace = True)
happiness_data["Country or region"].replace("Somaliland region", "Somaliland Region", inplace = True)
happiness_data["Country or region"].replace("North Macedonia", "Macedonia", inplace = True)
happiness_data["Country or region"].replace("Northern Cyprus", "North Cyprus", inplace = True)
happiness_data["Country or region"].replace("Trinidad and Tobago", "Trinidad & Tobago", inplace = True)
del happiness_data['index']
happiness_data
# Out:
#      Year  Overall rank Country or region  Score  GDP per capita  \
# 0    2019             1           Finland  7.769         1.34000
# 1    2019             2           Denmark  7.600         1.38300
# 2    2019             3            Norway  7.554         1.48800
# 3    2019             4           Iceland  7.494         1.38000
# 4    2019             5       Netherlands  7.488         1.39600
# ..    ...           ...               ...    ...             ...
# 777  2015           154            Rwanda  3.465         0.22208
# 778  2015           155             Benin  3.340         0.28665
# 779  2015           156             Syria  3.006         0.66320
# 780  2015           157           Burundi  2.905         0.01530
# 781  2015           158              Togo  2.839         0.20868
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           1.58700                  0.98600                       0.59600
# ...

# %%
group_country = happiness_data.groupby("Country or region")
pd.set_option("display.max_rows", None, "display.max_columns", None)
group_country.count()
# Out:
#                           Year  Overall rank  Score  GDP per capita  \
# Country or region
# Afghanistan                  5             5      5               5
# Albania                      5             5      5               5
# Algeria                      5             5      5               5
# Angola                       4             4      4               4
# Argentina                    5             5      5               5
# Armenia                      5             5      5               5
# Australia                    5             5      5               5
# Austria                      5             5      5               5
# Azerbaijan                   5             5      5               5
# Bahrain                      5             5      5               5
# Bangladesh                   5             5      5               5
# Belarus                      5             5      5               5
# ...

# %%
country_count = happiness_data["Country or region"].value_counts()

happiness_data_drop = happiness_data[~happiness_data['Country or region'].isin(country_count[country_count < 5].index)]

happiness_data_final = happiness_data_drop.reset_index()
del happiness_data_final['index']
happiness_data_final
# Out:
#      Year  Overall rank        Country or region  Score  GDP per capita  \
# 0    2019             1                  Finland  7.769        1.340000
# 1    2019             2                  Denmark  7.600        1.383000
# 2    2019             3                   Norway  7.554        1.488000
# 3    2019             4                  Iceland  7.494        1.380000
# 4    2019             5              Netherlands  7.488        1.396000
# 5    2019             6              Switzerland  7.480        1.452000
# 6    2019             7                   Sweden  7.343        1.387000
# 7    2019             8              New Zealand  7.307        1.303000
# 8    2019             9                   Canada  7.278        1.365000
# 9    2019            10                  Austria  7.246        1.376000
# 10   2019            11                Australia  7.228        1.372000
# 11   2019            12               Costa Rica  7.167        1.034000
# ...

# %%
# Group data by Country
gr_country = happiness_data_final.groupby(['Country or region'])
country = happiness_data_final['Country or region'].unique()
# Caluculate user defined statistics
mean_score = gr_country['Score'].mean()
mean_gdp = gr_country['GDP per capita'].mean()
mean_social = gr_country['Social support'].mean()
mean_health = gr_country['Healthy life expectancy'].mean()
mean_freedom = gr_country['Freedom to make life choices'].mean()
mean_generosity = gr_country['Generosity'].mean()
mean_corrupt = gr_country['Perceptions of corruption'].mean()
# Create dataframe with user defined statistics
summary_stats = pd.DataFrame({
   "Mean Score": mean_score,
   "Mean GDP": mean_gdp,
   'Mean Social Support': mean_social,
   "Mean Healthy Life Expectancy": mean_health,
   "Mean Freedom": mean_freedom,
   "Mean Generosity": mean_generosity,
   "Mean Corruption": mean_corrupt,
   })
summary_stats
# Out:
#                          Mean Score  Mean GDP  Mean Social Support  \
# Country or region
# Afghanistan                  3.5128  0.357113             0.409753
# Albania                      4.7126  0.938633             0.754931
# Algeria                      5.6676  1.012963             1.074205
# Argentina                    6.4594  1.111035             1.330960
# Armenia                      4.3932  0.839133             0.890873
# Australia                    7.2762  1.394885             1.409006
# Austria                      7.1420  1.398341             1.363963
# Azerbaijan                   5.2292  1.073644             1.031750
# Bahrain                      6.1138  1.390482             1.243464
# Bangladesh                   4.5802  0.523997             0.638336
# Belarus                      5.5980  1.085020             1.338153
# Belgium                      6.9214  1.375398             1.357493
# Benin                        3.9010  0.376745             0.340470
# ...

# %%
df = happiness_data_final
ranks = df.set_index('Overall rank')
ranks.head()

is_2015 = df['Year']=="2015"
is_2016 = df['Year']=="2016"
is_2017 = df['Year']=="2017"
is_2018 = df['Year']=="2018"
df_2015 = df[is_2015]
df_2016 = df[is_2016]
df_2017 = df[is_2017]
df_2018 = df[is_2018]
top_2015 = df_2015.iloc[0:10, 0:10]
top_2016 = df_2016.iloc[0:10, 0:10]
top_2017 = df_2017.iloc[0:10, 0:10]
top_2018 = df_2018.iloc[0:10, 0:10]
top_2019 = df.iloc[0:10, 0:10]
bottom_2015 = df_2015.iloc[-11:-1, 0:10]
bottom_2016 = df_2016.iloc[-11:-1, 0:10]
bottom_2017 = df_2017.iloc[-11:-1, 0:10]
bottom_2018 = df_2018.iloc[-11:-1, 0:10]
bottom_2019 = df.iloc[-11:-1, 0:10]

# %%
top_2015.drop('Overall rank', axis=1, inplace=True)
top_2015.drop('Score', axis=1, inplace=True)
top_2015.set_index(top_2015['Country or region'])[0:10].plot(kind='bar',stacked=True)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('2015 - Top 10 including contribution split')
plt.show()

# %%
top_2016.drop('Overall rank', axis=1, inplace=True)
top_2016.drop('Score', axis=1, inplace=True)
top_2016.set_index(top_2016['Country or region'])[0:10].plot(kind='bar',stacked=True)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('2016 - Top 10 including contribution split')
plt.show()

# %%
top_2017.drop('Overall rank', axis=1, inplace=True)
top_2017.drop('Score', axis=1, inplace=True)
top_2017.set_index(top_2017['Country or region'])[0:10].plot(kind='bar',stacked=True)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('2017 - Top 10 including contribution split')
plt.show()

# %%
top_2018.drop('Overall rank', axis=1, inplace=True)
top_2018.drop('Score', axis=1, inplace=True)
top_2018.set_index(top_2018['Country or region'])[0:10].plot(kind='bar',stacked=True)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('2018 - Top 10 including contribution split')
plt.show()

# %%
top_2019.drop('Overall rank', axis=1, inplace=True)
top_2019.drop('Score', axis=1, inplace=True)
top_2019.set_index(top_2019['Country or region'])[0:10].plot(kind='bar',stacked=True)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('2019 - Top 10 including contribution split')
plt.show()

# %%
bottom_2015.drop('Overall rank', axis=1, inplace=True)
bottom_2015.drop('Score', axis=1, inplace=True)
bottom_2015.set_index(bottom_2015['Country or region'])[0:10].plot(kind='bar',stacked=True)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('2015 - Bottom 10 including contribution split')
plt.show()

# %%
bottom_2016.drop('Overall rank', axis=1, inplace=True)
bottom_2016.drop('Score', axis=1, inplace=True)
bottom_2016.set_index(bottom_2016['Country or region'])[0:10].plot(kind='bar',stacked=True)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('2016 - Bottom 10 including contribution split')
plt.show()

# %%
bottom_2017.drop('Overall rank', axis=1, inplace=True)
bottom_2017.drop('Score', axis=1, inplace=True)
bottom_2017.set_index(bottom_2017['Country or region'])[0:10].plot(kind='bar',stacked=True)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('2017 - Bottom 10 including contribution split')
plt.show()

# %%
bottom_2018.drop('Overall rank', axis=1, inplace=True)
bottom_2018.drop('Score', axis=1, inplace=True)
bottom_2018.set_index(bottom_2018['Country or region'])[0:10].plot(kind='bar',stacked=True)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('2018 - Bottom 10 including contribution split')
plt.show()

# %%
bottom_2019.drop('Overall rank', axis=1, inplace=True)
bottom_2019.drop('Score', axis=1, inplace=True)
bottom_2019.set_index(bottom_2019['Country or region'])[0:10].plot(kind='bar',stacked=True)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('2019 - Bottom 10 including contribution split')
plt.show()

# %%
labels = ["GDP", "Social", "Health", "Freedom", "Generosity", "Corruption"]

ave_gdp = happiness_data_final['GDP per capita'].mean()
ave_social = happiness_data_final['Social support'].mean()
ave_health = happiness_data_final['Healthy life expectancy'].mean()
ave_freedom = happiness_data_final['Freedom to make life choices'].mean()
ave_generosity = happiness_data_final['Generosity'].mean()
ave_corrupt = happiness_data_final['Perceptions of corruption'].mean()

sizes = [ave_gdp, ave_social, ave_health, ave_freedom, ave_generosity, ave_corrupt]

colors = ["crimson", "coral", "gold", "limegreen", "royalblue", "mediumpurple"]

explode = (0, 0.1, 0, 0, 0, 0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct="%1.1f%%", shadow=True, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x2317ddb07f0>,
# ...
#  [Text(-0.8363230240634778, 0.7145374723702878, 'GDP'),
#   Text(-0.4796284444914988, -1.0999802522021318, 'Social'),
#   Text(1.0142469344482425, -0.4257970830834128, 'Health'),
#   Text(0.929864732874572, 0.5876662135567274, 'Freedom'),
#   Text(0.45587071260094536, 1.0010903522623253, 'Generosity'),
#   Text(0.1245303581060318, 1.0929282638444224, 'Corruption')],
#  [Text(-0.4561761949437151, 0.38974771220197507, '27.5%'),
#   Text(-0.2797832592867076, -0.6416551471179102, '31.9%'),
#   Text(0.5532256006081322, -0.23225295440913424, '18.5%'),
#   Text(0.507198945204312, 0.32054520739457854, '12.1%'),
#   Text(0.24865675232778836, 0.5460492830521774, '6.4%'),
#   Text(0.06792564987601733, 0.596142689369685, '3.6%')])

# %%
# Scatterplot to see correlation between GDP and Life expectancy
plt.scatter(happiness_data_final["GDP per capita"], happiness_data_final["Healthy life expectancy"], marker="o", s=8)

plt.title("What is the Correlation between GDP per Capita and Life Expectancy?")
plt.xlabel("GDP per capita")
plt.ylabel("Healthy life expectancy")
plt.grid(axis='both')

plt.show()

corr_1 = round(st.pearsonr(happiness_data_final["GDP per capita"],happiness_data_final["Healthy life expectancy"])[0],2)
print(f"The correlation coefficient between GDP Per Captia and Healthy Life Expectancy is {corr_1}")
# Out:
# The correlation coefficient between GDP Per Captia and Healthy Life Expectancy is 0.78

# %%
# Scatterplot to see correlation between GDP and Overall Happiness
plt.scatter(happiness_data_final["GDP per capita"], happiness_data_final["Score"], marker="o", s=8)

plt.title("What is the Correlation between GDP per Capita and Overall Happiness?")
plt.xlabel("GDP per capita")
plt.ylabel("Score")
plt.grid(axis='both')

plt.show()

corr_2 = round(st.pearsonr(happiness_data_final["GDP per capita"],happiness_data_final["Score"])[0],2)
print(f"The correlation coefficient between GDP Per Captia and Score is {corr_2}")
# Out:
# The correlation coefficient between GDP Per Captia and Score is 0.79

# %%
# Scatterplot to see correlation between SocialSupport and Overall Happiness
plt.scatter(happiness_data_final["Social support"], happiness_data_final["Score"], marker="o", s=8)

plt.title("What is the Correlation between Social Support and Overall Happiness?")
plt.xlabel("Social support")
plt.ylabel("Score")
plt.grid(axis='both')

plt.show()

corr_3 = round(st.pearsonr(happiness_data_final["Social support"],happiness_data_final["Score"])[0],2)
print(f"The correlation coefficient between Social Support and Score is {corr_3}")
# Out:
# The correlation coefficient between Social Support and Score is 0.65

# %%
# Scatterplot to see correlation between Health and Overall Happiness
plt.scatter(happiness_data_final["Healthy life expectancy"], happiness_data_final["Score"], marker="o", s=8)

plt.title("What is the Correlation between Healthy life expectancy and Overall Happiness?")
plt.xlabel("Healthy life expectancy")
plt.ylabel("Score")
plt.grid(axis='both')

plt.show()

corr_4 = round(st.pearsonr(happiness_data_final["Healthy life expectancy"],happiness_data_final["Score"])[0],2)
print(f"The correlation coefficient between Healthy life expectancy and Score is {corr_4}")
# Out:
# The correlation coefficient between Healthy life expectancy and Score is 0.74

# %%
# Scatterplot to see correlation between Freedom and Overall Happiness
plt.scatter(happiness_data_final["Freedom to make life choices"], happiness_data_final["Score"], marker="o", s=8)

plt.title("What is the Correlation between Freedom to make life choices and Overall Happiness?")
plt.xlabel("Freedom to make life choices")
plt.ylabel("Score")
plt.grid(axis='both')

plt.show()

corr_5 = round(st.pearsonr(happiness_data_final["Freedom to make life choices"],happiness_data_final["Score"])[0],2)
print(f"The correlation coefficient between Freedom to make life choices and Score is {corr_5}")
# Out:
# The correlation coefficient between Freedom to make life choices and Score is 0.54

# %%
# Scatterplot to see correlation between Generosity and Overall Happiness
plt.scatter(happiness_data_final["Generosity"], happiness_data_final["Score"], marker="o", s=8)

plt.title("What is the Correlation between Generosity and Overall Happiness?")
plt.xlabel("Generosity")
plt.ylabel("Score")
plt.grid(axis='both')

plt.show()

corr_6 = round(st.pearsonr(happiness_data_final["Generosity"],happiness_data_final["Score"])[0],2)
print(f"The correlation coefficient between Generosity and Score is {corr_6}")
# Out:
# The correlation coefficient between Generosity and Score is 0.14

# %%
# Scatterplot to see correlation between Corruption and Overall Happiness
plt.scatter(happiness_data_final["Perceptions of corruption"], happiness_data_final["Score"], marker="o", s=8)

plt.title("What is the Correlation between Perceptions of corruption and Overall Happiness?")
plt.xlabel("Perceptions of corruption")
plt.ylabel("Score")
plt.grid(axis='both')

plt.show()

happiness_data_final['Perceptions of corruption'] = np.nan_to_num(happiness_data_final['Perceptions of corruption'])
corr_7 = round(st.pearsonr(happiness_data_final["Perceptions of corruption"],happiness_data_final["Score"])[0],2)
print(f"The correlation coefficient between Perceptions of corruption and Score is {corr_7}")
# Out:
# The correlation coefficient between Perceptions of corruption and Score is 0.42

# %%
# Adding Correlation matrix to summarize the correlation of all of our data points
happiness_filter = happiness_data_final.filter(items=['Score', 'GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption'])
corr_matrix = happiness_filter.corr()
sn.heatmap(corr_matrix, annot = True)
plt.title('World Happiness Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'World Happiness Correlation Matrix')

# %%
# Line plots that shows the change in happiness scores of the top ten countries from 2019 over time
# Filter and create filtered df's each specific country

finland = happiness_data_final['Country or region']== 'Finland'
finland_df = happiness_data_final[finland]
sort_finland = finland_df.sort_values(by=['Year'])

denmark = happiness_data_final['Country or region']== 'Denmark'
denmark_df = happiness_data_final[denmark]
sort_denmark = denmark_df.sort_values(by=['Year'])

norway = happiness_data_final['Country or region']== 'Norway'
norway_df = happiness_data_final[norway]
sort_norway = norway_df.sort_values(by=['Year'])

iceland = happiness_data_final['Country or region']== 'Iceland'
iceland_df = happiness_data_final[iceland]
sort_iceland = iceland_df.sort_values(by=['Year'])

netherlands = happiness_data_final['Country or region']== 'Netherlands'
netherlands_df = happiness_data_final[netherlands]
sort_netherlands = netherlands_df.sort_values(by=['Year'])

switzerland = happiness_data_final['Country or region']== 'Switzerland'
switzerland_df = happiness_data_final[switzerland]
sort_switzerland = switzerland_df.sort_values(by=['Year'])

sweden = happiness_data_final['Country or region']== 'Sweden'
sweden_df = happiness_data_final[sweden]
sort_sweden = sweden_df.sort_values(by=['Year'])

newzealand = happiness_data_final['Country or region']== 'New Zealand'
newzealand_df = happiness_data_final[newzealand]
sort_newzealand = newzealand_df.sort_values(by=['Year'])

canada = happiness_data_final['Country or region']== 'Canada'
canada_df = happiness_data_final[canada]
sort_canada = canada_df.sort_values(by=['Year'])

austria = happiness_data_final['Country or region']== 'Austria'
austria_df = happiness_data_final[austria]
sort_austria = austria_df.sort_values(by=['Year'])

# %%
# Use our filtered df's to create line plot
top_countries = ['Finland', 'Denmark', 'Norway', 'Iceland', 'Netherlands', 'Switzerland', 'Sweden', 'New Zealand', 'Canada', 'Austria']


fig = plt.figure(figsize = (15,12) )
plt.plot('Year', 'Score', data = sort_finland, color = 'blue')
plt.plot('Year', 'Score', data = sort_denmark, color = 'pink')
plt.plot('Year', 'Score', data = sort_norway, color = 'red')
plt.plot('Year', 'Score', data = sort_iceland, color = 'green')
plt.plot('Year', 'Score', data = sort_netherlands, color = 'yellow')
plt.plot('Year', 'Score', data = sort_switzerland, color = 'orange')
plt.plot('Year', 'Score', data = sort_sweden, color = 'brown')
plt.plot('Year', 'Score', data = sort_newzealand, color = 'purple')
plt.plot('Year', 'Score', data = sort_canada, color = 'cyan')
plt.plot('Year', 'Score', data = sort_austria, color = 'black')
plt.grid(color='grey', linestyle='--', linewidth=.5)
plt.legend(labels = top_countries, loc = "upper left")
plt.title("Happiness Score of the Top 10 Countries Over Time", fontsize = 20)
plt.ylabel("Happiness Score", fontsize = 15)
plt.xlabel("Years",fontsize = 15)
plt.show()
